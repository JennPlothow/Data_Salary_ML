# %%
import pandas as pd

# URL do arquivo XLSX
url = "https://github.com/JennPlothow/Data_Salary_ML/raw/main/dados_sl.xlsx"

# Carregar o arquivo XLSX diretamente da URL usando o Pandas
df = pd.read_excel(url)

# Exibir os dados como tabela
df
# Out:
#       Unnamed: 0  ano_trabalho nível_experiência tipo_emprego  \
# 0              0          2023            JUNIOR    Full-time
# 1              1          2023            JUNIOR    Full-time
# 2              2          2023            JUNIOR    Full-time
# 3              3          2023            JUNIOR    Full-time
# 4              4          2023            JUNIOR    Full-time
# ...          ...           ...               ...          ...
# 3756        3756          2021             PLENO    Full-time
# 3757        3757          2021             PLENO    Full-time
# 3758        3758          2021            SENIOR    Full-time
# 3759        3759          2020             PLENO    Full-time
# 3760        3760          2020            SENIOR    Full-time
#
#                      Cargo  salário salário_moeda tamanho da empresa Código  \
# 0        Applied Scientist   213660           USD             GRANDE     US
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('nível_experiência').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['tipo_emprego'].value_counts()
    for x_label, grp in _df_15.groupby('nível_experiência')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('nível_experiência')
_ = plt.ylabel('tipo_emprego')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_17['nível_experiência'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_17, x='Unnamed: 0', y='nível_experiência', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
_df_7.plot(kind='scatter', x='ano_trabalho', y='salário', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_6.plot(kind='scatter', x='Unnamed: 0', y='ano_trabalho', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_5.groupby('tamanho da empresa').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_3.groupby('nível_experiência').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['ano_trabalho'].plot(kind='hist', bins=20, title='ano_trabalho')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
plt.gca().spines[['top', 'right',]].set_visible(False)
